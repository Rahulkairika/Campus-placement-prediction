# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn as sk
from matplotlib import pyplot as plt

# %%
data=pd.read_csv("placedata v2.0 synthetic.csv")

# %%
data
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
data.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# ...

# %%
data.tail()
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 9995                 72               3.9                       Yes
# 9996                 90               4.8                        No
# 9997                 70               4.8                       Yes
# 9998                 87               4.8                       Yes
# 9999                 66               3.8                        No
#
#      PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 9995                No         85         66       NotPlaced
# ...

# %%
data.shape
# Out:
# (10000, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
data.isnull().sum()

# %%
data.describe()

# %%
data.columns

# %%
data["Internships"].value_counts()

# %%
data["Internships"].min()

# %%
data["Internships"].max()

# %%
data.dtypes

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data = data.drop('StudentID', axis=1)

# %%
data.head()

# %%
data['ExtracurricularActivities']=le.fit_transform(data['ExtracurricularActivities'])
data['PlacementTraining']=le.fit_transform(data['PlacementTraining'])
data['PlacementStatus']=le.fit_transform(data['PlacementStatus'])

# %%
data.head(10)

# %%
sns.boxplot(data['PlacementStatus'])
# Out:
# <Axes: >

# %%
y=data['PlacementStatus']
X=data.drop(columns=['PlacementStatus'])

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()

# %%
names=X.columns

# %%
X=scale.fit_transform(X)

# %%
X

# %%
X=pd.DataFrame(X,columns=names)

# %%
X.head()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X ,y ,test_size=0.3,random_state=42)

# %%
train_test_split

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# %%
#classification
#Logisticregression
from sklearn.linear_model import LogisticRegression

# %%
logi=LogisticRegression()

# %%
logi.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
ytr=logi.predict(x_train)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
print(accuracy_score(y_train,ytr))
# Out:
# 0.8027142857142857

# %%
pred=logi.predict(x_test)
cm=confusion_matrix(y_test,pred)
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
import pickle

# %%
pickle.dump(logi,open("model1.pkl","wb"))

# %%
pickle.dump(scale,open("scale1.pkl","wb"))

# %%
data

# %%
data['PlacementStatus']

# %%
data.head(10)

# %%
logi.predict([[7.5,1,1,1,65,4.4,0,0,61,79]])

# %%
logi.predict([[-0.621794,-0.073889,-0.030648,1.091319,0.312528,1.156555,0.841566,-1.651836,0.943496,0.616487]])
